# %%
print("Python Öğreniyorum")
# Out:
# Python Öğreniyorum

# %%
ad = 'Kağan'
soyad = 'Yalçınkaya'
print(ad, "", soyad) # ad ve soyadı yazdırır.
# Out:
# Kağan  Yalçınkaya

# %%
"""Kağan Yalçınkaya 
İstanbul
37 """
# Out:
# 'Kağan Yalçınkaya \nİstanbul\n37 '

# %%
sehir = 'istanbul'
print(sehir)

puan = int (50)
print(puan)
puan = puan +25
print("yeni puan", puan)
# Out:
# istanbul
# 50
# yeni puan 75

# %%
tam_sayi = 10
ondalikli_sayi = 10.5
yazi = "residentevil"
boolean = True
sayi ='10'

print(type(tam_sayi))
print(type(ondalikli_sayi))
print(type(yazi))
print(type(boolean))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
if type(tam_sayi) == type(yazi):
    print("aynı tür.")
else:
    print("İki değer farklı.")
# Out:
# İki değer farklı.

# %%
toplama = 15+4
cikarma =15-4
bolme = 15/4
carpma = 15*4
mod= 15%4
ust_alma = 2**8

print(toplama)
print(cikarma)
print(carpma)
print(bolme)
print(mod)
print(ust_alma)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 256

# %%
a = 8
b = 12

print(a > b)
print(a < b)
print(a == b)

sayi = int(input())

if sayi == 100:
    print("100'e eşittir.")
else:
    print("100'e eşit değildir.")
# Out:
# False
# True
# False
# 100'e eşit değildir.

# %%
yas = 22
ogrenci_mi = False

print(yas > 18 and ogrenci_mi)
print(yas > 18 or ogrenci_mi)
print(not ogrenci_mi)
# Out:
# False
# True
# True

# %%
sayi = int(input())

if sayi >= 0:
    print("Pozitif")
else:
    print("Negatif")
# Out:
# Pozitif

# %%
sayi = int(input())

if sayi > 0:
    print("Pozitif")
elif sayi < 0:
    print("Negatif")
else:
    print("Sıfır")
# Out:
# Pozitif

# %%
ad = "Kağan"
soyad = "Yalçınkaya"

tam_ad = ad + " " + soyad

print(tam_ad)
# Out:
# Kağan Yalçınkaya

# %%
print(len(ad))
print(len(soyad))
# Out:
# 5
# 10

# %%
print(ad.upper())
# Out:
# KAĞAN

# %%
print(soyad.lower())
# Out:
# yalçınkaya

# %%
sayi1 = int(input("Birinci sayı "))
sayi2 = int(input("İkinci sayıyı "))

carpim = sayi1 * sayi2

print("Çarpım sonucu:", carpim)
# Out:
# Çarpım sonucu: 500
